# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
def gradient_descent(x, y, learning_rate, iterations):
    m = b = 0
    n = len(x)
    prev_cost = 0
    plt.scatter(x, y, color='red', marker='+', linewidth=5)
    for i in range(iterations):
        y_predicted = m * x + b
        plt.plot(x, y_predicted, color='green')
        cost = (1/n)*sum((y-y_predicted)**2)
        if (abs(cost-prev_cost)<0.000001):
            break
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum((y-y_predicted))
        m = m - learning_rate * md
        b = b - learning_rate * md
        prev_cost = cost
        print("m {}, b {}, cost {}, iteration {}".format(m, b, cost, i))
        
    return m, b

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

# %% [markdown]
# Gradient descent is fastest with a learning rate of 0.04

# %%
gradient_descent(x, y, 0.01, 1000)
# Out:
# m 0.62, b 0.62, cost 89.0, iteration 0
# m 1.0664, b 1.0664, cost 46.3192, iteration 1
# m 1.3878080000000002, b 1.3878080000000002, cost 24.157761280000003, iteration 2
# m 1.6192217600000003, b 1.6192217600000003, cost 12.643558807551997, iteration 3
# m 1.7858396672000003, b 1.7858396672000003, cost 6.656083145034952, iteration 4
# m 1.9058045603840001, b 1.9058045603840001, cost 3.5388463290101146, iteration 5
# m 1.9921792834764802, b 1.9921792834764802, cost 1.9132735721281262, iteration 6
# m 2.0543690841030657, b 2.0543690841030657, cost 1.0636666771131011, iteration 7
# m 2.0991457405542073, b 2.0991457405542073, cost 0.6182552786871867, iteration 8
# m 2.1313849331990293, b 2.1313849331990293, cost 0.3837718772271013, iteration 9
# m 2.154597151903301, b 2.154597151903301, cost 0.2596365464986065, iteration 10
# m 2.1713099493703765, b 2.1713099493703765, cost 0.19342781355261407, iteration 11
# m 2.183343163546671, b 2.183343163546671, cost 0.15776818259604541, iteration 12
# m 2.1920070777536034, b 2.1920070777536034, cost 0.13831957277405607, iteration 13
# m 2.1982450959825943, b 2.1982450959825943, cost 0.12754430030578218, iteration 14
# m 2.202736469107468, b 2.202736469107468, cost 0.12145935759991007, iteration 15
# m 2.205970257757377, b 2.205970257757377, cost 0.1179456134511959, iteration 16
# m 2.2082985855853114, b 2.2082985855853114, cost 0.11586538539250978, iteration 17
# m 2.2099749816214245, b 2.2099749816214245, cost 0.11460072894065199, iteration 18
# m 2.2111819867674254, b 2.2111819867674254, cost 0.11381101935312021, iteration 19
# m 2.2120510304725465, b 2.2120510304725465, cost 0.11330507349126329, iteration 20
# m 2.2126767419402333, b 2.2126767419402333, cost 0.11297326766006704, iteration 21
# m 2.213127254196968, b 2.213127254196968, cost 0.1127512025997604, iteration 22
# m 2.213451623021817, b 2.213451623021817, cost 0.11260004309195809, iteration 23
# m 2.213685168575708, b 2.213685168575708, cost 0.11249573249712566, iteration 24
# m 2.2138533213745095, b 2.2138533213745095, cost 0.11242297424045343, iteration 25
# m 2.213974391389647, b 2.213974391389647, cost 0.11237180413629036, iteration 26
# m 2.2140615618005457, b 2.2140615618005457, cost 0.11233559195308103, iteration 27
# m 2.214124324496393, b 2.214124324496393, cost 0.11230984592443341, iteration 28
# m 2.214169513637403, b 2.214169513637403, cost 0.1122914781675148, iteration 29
# m 2.21420204981893, b 2.21420204981893, cost 0.11227834119104751, iteration 30
# m 2.21422547586963, b 2.21422547586963, cost 0.11226892808792444, iteration 31
# m 2.2142423426261337, b 2.2142423426261337, cost 0.11226217425120949, iteration 32
# m 2.2142544866908165, b 2.2142544866908165, cost 0.11225732372173654, iteration 33
# m 2.2142632304173877, b 2.2142632304173877, cost 0.1122538376820826, iteration 34
# m 2.214269525900519, b 2.214269525900519, cost 0.11225133102100054, iteration 35
# m 2.214274058648374, b 2.214274058648374, cost 0.11224952792924547, iteration 36
# m 2.2142773222268293, b 2.2142773222268293, cost 0.11224823058665107, iteration 37
# (2.2142773222268293, 2.2142773222268293)
